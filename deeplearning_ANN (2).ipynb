# %%
import numpy as np

# %%
u=np.array([3,4])
v=np.array([30,40])

# %%
print(np.linalg.norm(u))
print(np.linalg.norm(v))
# Out:
# 5.0
# 50.0

# %%
def director_vector(x):
  return x/np.linalg.norm(x)

# %%
print(director_vector(u))
print(director_vector(v))
# Out:
# [0.6 0.8]
# [0.6 0.8]

# %%
import math
def dot_product(x,y,theta):
  x_norm=np.linalg.norm(x)
  y_norm=np.linalg.norm(y)
  dot_prod=x_norm*y_norm*math.cos(math.radians(theta))
  return dot_prod

# %%
theta=0
math.cos(math.radians(theta))
# Out:
# 1.0

# %%
dot_product([3,5],[8,2],45)
# Out:
# 34.00000000000001

# %%
dot_product([3,5],[8,2],0)
# Out:
# 48.083261120685236

# %%
math.sqrt((3**2)+(5**2))*math.sqrt((8**2)+(2**2))
# Out:
# 48.083261120685236

# %%
print('{:.20f}'.format(dot_product([3,5],[8,2],90)))
# Out:
# 0.00000000000000294425

# %%
print('{:.10f}'.format(dot_product([3,5],[8,2],90)))
# Out:
# 0.0000000000

# %%
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import fashion_mnist

# %%
(X_train,Y_train),(x_test,y_test)=fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
X_train

# %%
plt.imshow(X_train[0])
print('Label',Y_train[0])
# Out:
# Label 9

# %%
X_train.shape,x_test.shape,Y_train.shape,y_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %%
plt.imshow(X_train[9])
print('Label',Y_train[9])
# Out:
# Label 5

# %%
x_train=X_train.reshape((X_train.shape[0],-1))

# %%
x_test=x_test.reshape((x_test.shape[0],-1))

# %%
x_train.shape,x_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras import optimizers

# %%
model=Sequential()
model.add(Dense(50,input_shape=(784,),activation='sigmoid'))
model.add(Dense(50,activation='sigmoid'))
model.add(Dense(50,activation='sigmoid'))
model.add(Dense(50,activation='sigmoid'))
model.add(Dense(10,activation='softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 50)                39250
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                510
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# ...
# Total params: 47,410
# Trainable params: 47,410
# Non-trainable params: 0
# ...

# %%
(784*50)+50
# Out:
# 39250

# %%
(50*50)+50
# Out:
# 2550

# %%
(50*10)+10
# Out:
# 510

# %%
sgd=optimizers.SGD(lr=0.01)
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train=to_categorical(Y_train,num_classes=10)
y_test=to_categorical(y_test,num_classes=10)

# %%
history=model.fit(x_train,y_train,batch_size=200,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 300/300 [==============================] - 2s 3ms/step - loss: 2.3062 - accuracy: 0.0979
# Epoch 2/100
# 300/300 [==============================] - 1s 3ms/step - loss: 2.3056 - accuracy: 0.0992
# Epoch 3/100
# 300/300 [==============================] - 1s 3ms/step - loss: 2.3053 - accuracy: 0.0999
# Epoch 4/100
# 300/300 [==============================] - 1s 3ms/step - loss: 2.3042 - accuracy: 0.0988
# Epoch 5/100
# 300/300 [==============================] - 1s 4ms/step - loss: 2.3047 - accuracy: 0.0996
# Epoch 6/100
# 300/300 [==============================] - 1s 4ms/step - loss: 2.3043 - accuracy: 0.1007
# Epoch 7/100
# 300/300 [==============================] - 1s 4ms/step - loss: 2.3039 - accuracy: 0.1010
# Epoch 8/100
# 300/300 [==============================] - 1s 4ms/step - loss: 2.3040 - accuracy: 0.0998
# Epoch 9/100
# 300/300 [==============================] - 1s 3ms/step - loss: 2.3037 - accuracy: 0.1022
# Epoch 10/100
# ...

# %%
results=model.evaluate(x_test,y_test)

# %%
x_test.shape,y_test.shape
# Out:
# ((10000, 784), (10000, 10, 10))

# %%
model=Sequential()
model.add(Dense(2000,input_shape=(3072,),activation='relu'))
model.add(Dense(1000,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(250,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
adam=optimizers.Adam(lr=0.01)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,batch_size=500,epochs=50,verbose=1)
